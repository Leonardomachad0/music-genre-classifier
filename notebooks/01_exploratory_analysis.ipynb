# %%
# Importações necessárias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Configurações de visualização
plt.style.use('ggplot')
sns.set_palette('husl')

print("Bibliotecas importadas com sucesso!")
# Out:
# Bibliotecas importadas com sucesso!
# Shape: (1000, 60)
#
# Colunas: ['filename', 'length', 'chroma_stft_mean', 'chroma_stft_var', 'rms_mean', 'rms_var', 'spectral_centroid_mean', 'spectral_centroid_var', 'spectral_bandwidth_mean', 'spectral_bandwidth_var', 'rolloff_mean', 'rolloff_var', 'zero_crossing_rate_mean', 'zero_crossing_rate_var', 'harmony_mean', 'harmony_var', 'perceptr_mean', 'perceptr_var', 'tempo', 'mfcc1_mean', 'mfcc1_var', 'mfcc2_mean', 'mfcc2_var', 'mfcc3_mean', 'mfcc3_var', 'mfcc4_mean', 'mfcc4_var', 'mfcc5_mean', 'mfcc5_var', 'mfcc6_mean', 'mfcc6_var', 'mfcc7_mean', 'mfcc7_var', 'mfcc8_mean', 'mfcc8_var', 'mfcc9_mean', 'mfcc9_var', 'mfcc10_mean', 'mfcc10_var', 'mfcc11_mean', 'mfcc11_var', 'mfcc12_mean', 'mfcc12_var', 'mfcc13_mean', 'mfcc13_var', 'mfcc14_mean', 'mfcc14_var', 'mfcc15_mean', 'mfcc15_var', 'mfcc16_mean', 'mfcc16_var', 'mfcc17_mean', 'mfcc17_var', 'mfcc18_mean', 'mfcc18_var', 'mfcc19_mean', 'mfcc19_var', 'mfcc20_mean', 'mfcc20_var', 'label']
#
# ...

# %%
# Carregando o dataset de features
df = pd.read_csv('../data/features_30_sec.csv')

# Primeiras informações
print(f"Shape: {df.shape}")
print(f"\nColunas: {df.columns.tolist()}")
print(f"\nPrimeiras linhas:")
df.head()
# Out:
# Shape: (1000, 60)
#
# Colunas: ['filename', 'length', 'chroma_stft_mean', 'chroma_stft_var', 'rms_mean', 'rms_var', 'spectral_centroid_mean', 'spectral_centroid_var', 'spectral_bandwidth_mean', 'spectral_bandwidth_var', 'rolloff_mean', 'rolloff_var', 'zero_crossing_rate_mean', 'zero_crossing_rate_var', 'harmony_mean', 'harmony_var', 'perceptr_mean', 'perceptr_var', 'tempo', 'mfcc1_mean', 'mfcc1_var', 'mfcc2_mean', 'mfcc2_var', 'mfcc3_mean', 'mfcc3_var', 'mfcc4_mean', 'mfcc4_var', 'mfcc5_mean', 'mfcc5_var', 'mfcc6_mean', 'mfcc6_var', 'mfcc7_mean', 'mfcc7_var', 'mfcc8_mean', 'mfcc8_var', 'mfcc9_mean', 'mfcc9_var', 'mfcc10_mean', 'mfcc10_var', 'mfcc11_mean', 'mfcc11_var', 'mfcc12_mean', 'mfcc12_var', 'mfcc13_mean', 'mfcc13_var', 'mfcc14_mean', 'mfcc14_var', 'mfcc15_mean', 'mfcc15_var', 'mfcc16_mean', 'mfcc16_var', 'mfcc17_mean', 'mfcc17_var', 'mfcc18_mean', 'mfcc18_var', 'mfcc19_mean', 'mfcc19_var', 'mfcc20_mean', 'mfcc20_var', 'label']
#
# Primeiras linhas:
# ...

# %%
# Distribuição dos gêneros
print("Distribuição dos gêneros:")
print(df['label'].value_counts())

# Dados faltando
print(f"\nDados faltando: {df.isnull().sum().sum()}")
# Out:
# Distribuição dos gêneros:
# label
# blues        100
# classical    100
# country      100
# disco        100
# hiphop       100
# jazz         100
# metal        100
# pop          100
# reggae       100
# rock         100
# Name: count, dtype: int64
#
# Dados faltando: 0

# %%
# Visualizar distribuição
plt.figure(figsize=(10, 5))
df['label'].value_counts().plot(kind='bar', color=sns.color_palette('husl', 10))
plt.title('Distribuição de músicas por gênero')
plt.xlabel('Gênero')
plt.ylabel('Quantidade')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Separar features e label
X = df.drop(['filename', 'length', 'label'], axis=1)
y = df['label']

print(f"Features: {X.shape[1]}")
print(f"Exemplos: {X.shape[0]}")
print(f"\nGêneros únicos: {y.unique()}")
# Out:
# Features: 57
# Exemplos: 1000
#
# Gêneros únicos: <ArrowStringArray>
# [    'blues', 'classical',   'country',     'disco',    'hiphop',      'jazz',
#      'metal',       'pop',    'reggae',      'rock']
# Length: 10, dtype: str

# %%
# Correlação das features com o label (usando codificação numérica)
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Top 10 features mais correlacionadas com o gênero
correlacoes = pd.DataFrame(X)
correlacoes['label_encoded'] = y_encoded

corr_com_label = correlacoes.corr()['label_encoded'].drop('label_encoded').abs().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
corr_com_label.head(15).plot(kind='bar', color=sns.color_palette('husl', 15))
plt.title('Top 15 features mais correlacionadas com gênero musical')
plt.xlabel('Feature')
plt.ylabel('Correlação absoluta')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

print("\nTop 10 features:")
print(corr_com_label.head(10))
# Out:
# Top 10 features:
# spectral_bandwidth_mean    0.388800
# rolloff_mean               0.385213
# spectral_centroid_mean     0.378395
# chroma_stft_mean           0.366451
# mfcc2_mean                 0.354846
# mfcc1_mean                 0.340101
# spectral_centroid_var      0.317572
# rolloff_var                0.273637
# zero_crossing_rate_var     0.272210
# zero_crossing_rate_mean    0.268278
# Name: label_encoded, dtype: float64

# %%
# Distribuição do spectral_bandwidth_mean por gênero
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='label', y='spectral_bandwidth_mean',
            hue='label', palette='husl', legend=False)
plt.title('Spectral Bandwidth por Gênero Musical')
plt.xlabel('Gênero')
plt.ylabel('Spectral Bandwidth Mean')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Distribuição do tempo (BPM) por gênero
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='label', y='tempo',
            hue='label', palette='husl', legend=False)
plt.title('Tempo (BPM) por Gênero Musical')
plt.xlabel('Gênero')
plt.ylabel('BPM')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Heatmap das primeiras features (MFCCs principais)
mfcc_cols = [col for col in X.columns if 'mfcc' in col and 'mean' in col]

plt.figure(figsize=(12, 8))
sns.heatmap(df[mfcc_cols].corr(), 
            annot=False, 
            cmap='coolwarm',
            center=0)
plt.title('Correlação entre MFCCs')
plt.tight_layout()
plt.show()
